# %%
import os
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint

# Path ke dataset yang telah dibagi
train_dir = r"D:\KULIAH\SEMESTER 5\PENGHLIHATAN DAN ANALISIS CITRA\DATASET\Klasifikasi\DATASET\train"
val_dir = r"D:\KULIAH\SEMESTER 5\PENGHLIHATAN DAN ANALISIS CITRA\DATASET\Klasifikasi\DATASET\val"

# Parameter model
input_size = (224, 224)  # Ukuran gambar input
batch_size = 32          # Ukuran batch
num_classes = len(os.listdir(train_dir))  # Jumlah kelas berdasarkan folder di train_dir
epochs = 20              # Jumlah epoch

# Data Augmentation dan Preprocessing
train_datagen = ImageDataGenerator(
    rescale=1.0/255.0,    # Normalisasi gambar ke rentang [0, 1]
    rotation_range=20,    # Rotasi acak hingga 20 derajat
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

val_datagen = ImageDataGenerator(
    rescale=1.0/255.0     # Normalisasi gambar ke rentang [0, 1]
)

# Generator dataset
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_size,
    batch_size=batch_size,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=input_size,
    batch_size=batch_size,
    class_mode='categorical'
)

# Arsitektur Model CNN
model = Sequential([
    Input(shape=(224, 224, 3)),  # Menggunakan Input layer
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')  # Output layer sesuai jumlah kelas
])

# Compile Model
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# Checkpoint untuk menyimpan model terbaik
checkpoint_path = "best_model.keras"  # Ubah ekstensi menjadi .keras
checkpoint = ModelCheckpoint(
    checkpoint_path, 
    monitor='val_accuracy', 
    save_best_only=True, 
    mode='max', 
    verbose=1
)

# Training Model
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=val_generator,
    callbacks=[checkpoint]
)

# Menyimpan Model Final
final_model_path = "final_model.keras"  # Ubah ekstensi menjadi .keras
model.save(final_model_path)
print(f"Model final disimpan di: {final_model_path}")

# Plotting Akurasi dan Loss
plt.figure(figsize=(12, 6))

# Plot Akurasi
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Akurasi Model')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Model')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Menampilkan plot
plt.tight_layout()
plt.show()
# Out:
# Found 2274 images belonging to 5 classes.
# Found 487 images belonging to 5 classes.
# D:\Anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3118 - loss: 1.7023
# D:\Anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1: val_accuracy improved from -inf to 0.47639, saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 136s 2s/step - accuracy: 0.3124 - loss: 1.6994 - val_accuracy: 0.4764 - val_loss: 1.2443
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4425 - loss: 1.3153
# Epoch 2: val_accuracy improved from 0.47639 to 0.53799, saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.4426 - loss: 1.3150 - val_accuracy: 0.5380 - val_loss: 1.1574
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4754 - loss: 1.2228
# Epoch 3: val_accuracy did not improve from 0.53799
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - accuracy: 0.4753 - loss: 1.2227 - val_accuracy: 0.5175 - val_loss: 1.0438
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5067 - loss: 1.1779
# Epoch 4: val_accuracy did not improve from 0.53799
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - accuracy: 0.5065 - loss: 1.1782 - val_accuracy: 0.4887 - val_loss: 1.1759
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5102 - loss: 1.1934
# Epoch 5: val_accuracy improved from 0.53799 to 0.58727, saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - accuracy: 0.5103 - loss: 1.1929 - val_accuracy: 0.5873 - val_loss: 0.9798
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5273 - loss: 1.1066
# Epoch 6: val_accuracy did not improve from 0.58727
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - accuracy: 0.5275 - loss: 1.1064 - val_accuracy: 0.5626 - val_loss: 1.0037
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5506 - loss: 1.0689
# Epoch 7: val_accuracy did not improve from 0.58727
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - accuracy: 0.5508 - loss: 1.0684 - val_accuracy: 0.5585 - val_loss: 0.9551
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5564 - loss: 1.0605
# Epoch 8: val_accuracy improved from 0.58727 to 0.59138, saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.5564 - loss: 1.0604 - val_accuracy: 0.5914 - val_loss: 0.9358
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5605 - loss: 1.0135
# Epoch 9: val_accuracy did not improve from 0.59138
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 117s 2s/step - accuracy: 0.5607 - loss: 1.0132 - val_accuracy: 0.5893 - val_loss: 0.8926
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5657 - loss: 0.9830
# Epoch 10: val_accuracy improved from 0.59138 to 0.61396, saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - accuracy: 0.5658 - loss: 0.9830 - val_accuracy: 0.6140 - val_loss: 0.8669
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5774 - loss: 0.9925
# Epoch 11: val_accuracy improved from 0.61396 to 0.66530, saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.5774 - loss: 0.9924 - val_accuracy: 0.6653 - val_loss: 0.8230
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6117 - loss: 0.9558
# Epoch 12: val_accuracy improved from 0.66530 to 0.68378, saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - accuracy: 0.6117 - loss: 0.9555 - val_accuracy: 0.6838 - val_loss: 0.8028
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6045 - loss: 0.9206
# Epoch 13: val_accuracy did not improve from 0.68378
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - accuracy: 0.6046 - loss: 0.9208 - val_accuracy: 0.6756 - val_loss: 0.7898
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5967 - loss: 0.9384
# Epoch 14: val_accuracy improved from 0.68378 to 0.70842, saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - accuracy: 0.5970 - loss: 0.9380 - val_accuracy: 0.7084 - val_loss: 0.7278
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6330 - loss: 0.8417
# Epoch 15: val_accuracy did not improve from 0.70842
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - accuracy: 0.6330 - loss: 0.8420 - val_accuracy: 0.6715 - val_loss: 0.7536
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6276 - loss: 0.8561
# Epoch 16: val_accuracy did not improve from 0.70842
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 125s 2s/step - accuracy: 0.6277 - loss: 0.8558 - val_accuracy: 0.6776 - val_loss: 0.7043
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6188 - loss: 0.9285
# Epoch 17: val_accuracy did not improve from 0.70842
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 118s 2s/step - accuracy: 0.6188 - loss: 0.9285 - val_accuracy: 0.6899 - val_loss: 0.7236
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6348 - loss: 0.8552
# Epoch 18: val_accuracy did not improve from 0.70842
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 118s 2s/step - accuracy: 0.6348 - loss: 0.8551 - val_accuracy: 0.6735 - val_loss: 0.7362
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6348 - loss: 0.8438
# Epoch 19: val_accuracy did not improve from 0.70842
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - accuracy: 0.6350 - loss: 0.8435 - val_accuracy: 0.7002 - val_loss: 0.7405
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6578 - loss: 0.8175
# Epoch 20: val_accuracy improved from 0.70842 to 0.72074, saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - accuracy: 0.6577 - loss: 0.8176 - val_accuracy: 0.7207 - val_loss: 0.6394
# Model final disimpan di: final_model.keras

# %%
import pandas as pd

# Fungsi untuk mengekstrak fitur dari gambar dan menyimpan ke Excel
def extract_features_and_save_to_excel(generator, model, output_file):
    features = []
    labels = []
    file_names = []

    for images, labels_batch in generator:
        feature_batch = model.predict(images)
        features.extend(feature_batch)
        labels.extend(labels_batch)
        file_names.extend(generator.filenames[generator.batch_index])

        if len(file_names) >= generator.samples:
            break

    # Konversi hasil ekstraksi fitur ke DataFrame
    df_features = pd.DataFrame(features)
    df_labels = pd.DataFrame(labels, columns=generator.class_indices.keys())
    df_file_names = pd.Series(file_names, name='File Name')

    # Gabungkan dalam satu DataFrame
    df_combined = pd.concat([df_file_names, df_labels], axis=1)
    df_combined.to_excel(output_file, index=False)
    print(f"Hasil fitur disimpan ke: {output_file}")

# Panggil fungsi untuk menyimpan hasil fitur
output_excel_file = 'feature_extraction_results.xlsx'
extract_features_and_save_to_excel(train_generator, model, output_excel_file)
